# %% [markdown]
# <a href="https://colab.research.google.com/github/PhanQuangHuy123/B-i-1_AI_-Phan-Quang-Huy-20146254/blob/main/AI_W9_31_03_2023(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test, y_test)= cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
import matplotlib.pyplot as plt
cifar = x_train[8]
plt.imshow(cifar,cmap=plt.cm.binary)
plt.show()
print ('So:',y_train[8])
# Out:
# So: [8]

# %%
for i in range (20):
  plt.subplot(4,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title('SO:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential 
from keras.layers import Dense
model = Sequential()
model.add(Dense(3000,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(1000,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 3000)              9219000
#
#  dense_1 (Dense)             (None, 1000)              3001000
#
#  dense_2 (Dense)             (None, 500)               500500
#
#  dense_3 (Dense)             (None, 10)                5010
#
# ...
# Total params: 12,725,510
# Trainable params: 12,725,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = x_test
y = y_test

# %%
x_train = x_train.reshape(50000,32*32*3)
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(10000,32*32*3)
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_test.shape
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
y_train  = to_categorical(y_train,10)
y_test = to_categorical (y_test,10)

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10 ,batch_size=128)
test_loss, test_acc = model.evaluate(x_test ,y_test)
print('Mat mat :',test_loss)
print('Do chinh xac :',test_acc)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 109s 277ms/step - loss: 2.1643 - accuracy: 0.1730
# Epoch 2/10
# 391/391 [==============================] - 107s 274ms/step - loss: 1.9701 - accuracy: 0.2705
# Epoch 3/10
# 391/391 [==============================] - 107s 273ms/step - loss: 1.8680 - accuracy: 0.3221
# Epoch 4/10
# 391/391 [==============================] - 112s 286ms/step - loss: 1.7919 - accuracy: 0.3514
# Epoch 5/10
# 391/391 [==============================] - 106s 270ms/step - loss: 1.7405 - accuracy: 0.3672
# Epoch 6/10
# 391/391 [==============================] - 106s 271ms/step - loss: 1.6963 - accuracy: 0.3878
# Epoch 7/10
# 391/391 [==============================] - 105s 268ms/step - loss: 1.6564 - accuracy: 0.4028
# Epoch 8/10
# 391/391 [==============================] - 103s 263ms/step - loss: 1.6177 - accuracy: 0.4177
# Epoch 9/10
# 391/391 [==============================] - 104s 266ms/step - loss: 1.5859 - accuracy: 0.4305
# Epoch 10/10
# ...

# %%
model.save('test1.h5')

# %%
from keras.utils.image_utils import img_to_array
from keras.utils import load_img
import numpy as np
img = load_img ('/content/drive/MyDrive/tiger-2535888__340.jpg',target_size=(32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape (1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 218ms/step
# array([5])

# %%
from keras.utils import load_img , img_to_array 
img = load
