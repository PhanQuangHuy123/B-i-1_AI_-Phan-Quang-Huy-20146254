# %% [markdown]
# <a href="https://colab.research.google.com/github/PhanQuangHuy123/B-i-1_AI_-Phan-Quang-Huy-20146254/blob/main/AI_W12_21_04_2023(MTCNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 24.9 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/ảnh tập thể.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 7/7 [==============================] - 0s 41ms/step
# {'box': [1368, 906, 68, 88], 'confidence': 0.9999999403953552, 'keypoints': {'left_eye': (1390, 942), 'right_eye': (1422, 941), 'nose': (1408, 961), 'mouth_left': (1391, 970), 'mouth_right': (1422, 970)}}
# {'box': [665, 905, 82, 102], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (691, 944), 'right_eye': (729, 949), 'nose': (708, 966), 'mouth_left': (687, 980), 'mouth_right': (722, 983)}}
# {'box': [1967, 928, 84, 99], 'confidence': 0.9999937415122986, 'keypoints': {'left_eye': (1987, 964), 'right_eye': (2029, 964), 'nose': (2008, 984), 'mouth_left': (1988, 1002), 'mouth_right': (2025, 1003)}}
# {'box': [1686, 815, 40, 48], 'confidence': 0.999991238117218, 'keypoints': {'left_eye': (1701, 833), 'right_eye': (1719, 833), 'nose': (1712, 842), 'mouth_left': (1702, 852), 'mouth_right': (1718, 852)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/ảnh tập thể.jpg'

img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
ax=plt.gca()

for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key ,value in face ['keypoints'].items():
    dot = plt.Circle(value, radius = 2 ,color='red')
    ax.add_patch(dot)
    plt.savefig('/content/drive/MyDrive/anh tap the(1).jpg')
plt.show()
# Out:
# ...
# 7/7 [==============================] - 0s 44ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/images.jpg'

img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
ax=plt.gca()

for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key ,value in face ['keypoints'].items():
    dot = plt.Circle(value, radius = 2 ,color='red')
    ax.add_patch(dot)
    plt.savefig('/content/drive/MyDrive/anh tap the deo khau trang(2).jpg')
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 73ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
def draw_faces (filename,result_list):
  data = plt.imread(filename)
  for i in range (len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2= x1+width, y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

# %%
filename='/content/drive/MyDrive/images.jpg'
img = plt.imread(filename)
detector= MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename , faces)
plt.savefig('/content/drive/MyDrive/anh tap the deo khau trang(3).jpg')
# Out:
# ...
# 2/2 [==============================] - 0s 43ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/tê giác.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n01871265', 'tusker', 0.36033708), ('n02408429', 'water_buffalo', 0.21309458), ('n02397096', 'warthog', 0.1551787)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/hà mã.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02398521', 'hippopotamus', 0.38567087), ('n01871265', 'tusker', 0.3570187), ('n02504013', 'Indian_elephant', 0.09099528)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/thực vât.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted: [('n03991062', 'pot', 0.70524687), ('n04522168', 'vase', 0.03042459), ('n12057211', "yellow_lady's_slipper", 0.028100617)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/thực vật (1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n03991062', 'pot', 0.096097454), ('n02206856', 'bee', 0.095873825), ('n13044778', 'earthstar', 0.088836215)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/nấm (1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted: [('n07734744', 'mushroom', 0.6099214), ('n13054560', 'bolete', 0.18715148), ('n13052670', 'hen-of-the-woods', 0.07349942)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/drive/MyDrive/hà mã.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# ...
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02398521', 'hippopotamus', 0.57893527), ('n02504013', 'Indian_elephant', 0.23157597), ('n01871265', 'tusker', 0.117347255)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/thực vật (1).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n07734744', 'mushroom', 0.30970314), ('n13054560', 'bolete', 0.20451921), ('n13052670', 'hen-of-the-woods', 0.08488133)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = '/content/rùa.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
print('Predicted:', decode_predictions(block4_pool_features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 732ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f2044c19f319> in <cell line: 17>()
#      15
#      16 block4_pool_features = model.predict(x)
# ---> 17 print('Predicted:', decode_predictions(block4_pool_features, top=3)[0])
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/resnet.py in decode_predictions(preds, top)
#     619 )
#     620 def decode_predictions(preds, top=5):
# --> 621     return imagenet_utils.decode_predictions(preds, top=top)
#     622
#     623
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     151
#     152     if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 153         raise ValueError(
#     154             "`decode_predictions` expects "
#     155             "a batch of predictions "
#
# ...
