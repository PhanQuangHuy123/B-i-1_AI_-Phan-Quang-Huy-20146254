# %% [markdown]
# <a href="https://colab.research.google.com/github/PhanQuangHuy123/B-i-1_AI_-Phan-Quang-Huy-20146254/blob/main/W7(50_Startups)_17_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url ="/content/50_Startups.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt 
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print (correlation )
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model #hoi quy tuyen tinh
model =linear_model.LinearRegression()
model.fit(X=pd.DataFrame (data['R&D Spend']),
          y=data['Profit'])
print ("He so intercept la :", model.intercept_) 
print ("He so coeffient la:", model.coef_)
model.score(X=pd.DataFrame (data['R&D Spend']),
          y=data['Profit'])# tinh do chinh xac
# Out:
# He so intercept la : 49032.89914125215
# He so coeffient la: [0.85429137]
# 0.9465353160804393

# %%
y_pred=model.predict (X=pd.DataFrame (data['R&D Spend']))
print(y_pred)
# Out:
# [190289.29389289 187938.71118575 180116.65707807 172369.00320589
#  170433.97345032 161694.19683741 164033.72501421 160345.46724972
#  152011.33380847 154396.82286103 136096.36397105 135036.08586475
#  129219.89081021 127621.20411029 151499.37407569 146869.43093301
#  115678.82583435 129897.69412683 127413.41482014 122860.50313037
#  114175.91374003 116000.34693472 112245.81324567 106725.35677792
#  114850.93206678 104275.40289851 113385.70276482 110633.79960036
#  105460.14271464 105079.09459155 101994.24845109 101261.18102569
#  103202.54108032  96440.90176556  88694.29012885  88342.27936946
#   73520.10196791  86681.47714396  66314.86331588  81973.10151051
#   73597.47513738  72861.58000754  69229.14164122  62279.31048036
#   67979.15105018  49887.38699921  50156.68526807  49032.89914125
#   49495.96777887  49032.89914125]

# %%
data.plot (kind= "scatter",x="R&D Spend",
           y= "Profit", figsize=(9,9),
           color = "black", xlim=(0,200000))
plt.plot(data["R&D Spend"],y_pred,color ="purple")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model =linear_model.LinearRegression()
X = pd.DataFrame([data["R&D Spend"],data["R&D Spend"]**2,data["R&D Spend"]**3]).T
y= data["Profit"]
model.fit (X,y)
print ('Intercept cua mo hinh :', model.intercept_)
print ("Coeffient cua mo hinh :", model.coef_)
print ('Do chinh xac cua mo hinh :', model.score(X,y))
# Out:
# Intercept cua mo hinh : 43108.76756818297
# Coeffient cua mo hinh : [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# Do chinh xac cua mo hinh : 0.9540709421464032

# %%
import numpy as np
range = np.arange(1,200000, 0.1)
X_range=pd.DataFrame([range,range**2,range**3]).T 
y_pred = model.predict(X=X_range)
data.plot(kind = 'scatter', x='R&D Spend', 
          y = 'Profit', figsize = (9,9), color = 'black',
          xlim = (0,200000))
plt.plot(range, y_pred, color = 'violet')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model =linear_model.LinearRegression()
X = pd.DataFrame([data["R&D Spend"],data["R&D Spend"]**1,data["R&D Spend"]**2,data["R&D Spend"]**3,data["R&D Spend"]**4,data["R&D Spend"]**5]).T
y= data["Profit"]
model.fit (X,y)
print ('Intercept cua mo hinh :', model.intercept_)
print ("Coeffient cua mo hinh :", model.coef_)
print ('Do chinh xac cua mo hinh :', model.score(X,y))
# Out:
# Intercept cua mo hinh : 62755.68250287384
# Coeffient cua mo hinh : [ 1.32995066e-19 -3.54087328e-15  8.53722437e-15  3.43374411e-10
#  -3.89058927e-15  1.21062645e-20]
# Do chinh xac cua mo hinh : 0.9088995842423597

# %%
import numpy as np 
range = np.arange (1,200000,0.1)
X_range = pd.DataFrame ([range ,range**1, range**2,range**3,range**4,range**5]).T
y_pred=model.predict (X=X_range)
data.plot (kind="scatter",x="R&D Spend",
           y= "Profit",figsize =(9,9),color='black',
           xlim=(0,200000))
plt.plot(range , y_pred,color="red")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X = data.loc[:,['R&D Spend', 'Administration']], y = data['Profit'])
print('Intercept là: ', model.intercept_)
print('Coefficent là: ', model.coef_)
print('Độ chính xác là: ', model.score(X = data.loc[:,['R&D Spend', 'Administration']],y = data['Profit']))
# Out:
# Intercept là:  54886.62062756297
# Coefficent là:  [ 0.86211798 -0.05299543]
# Độ chính xác là:  0.9478129385009173

# %%
model = linear_model.LinearRegression()
model.fit (X= data.loc[:,["R&D Spend","Administration","Marketing Spend"]],y=data["Profit"])
print ("Intercept la:", model.intercept_)
print ("Coeffient la :", model.coef_)
print ("Do chinh xac:", model.score(X= data.loc[:,["R&D Spend","Administration","Marketing Spend"]],y=data["Profit"]))
# Out:
# Intercept la: 50122.19298986524
# Coeffient la : [ 0.80571505 -0.02681597  0.02722806]
# Do chinh xac: 0.9507459940683246
